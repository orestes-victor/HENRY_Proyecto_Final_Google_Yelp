# %% [markdown]
# # **Feature Engineering**
# Aca detallaremos todos los pasos necesarios para convertir nuestra data en el formato adecuado para nuestro modelo de recomendación, usando tablas de Googlemaps, Yelp y Tripadvisor.

# %%
import pandas as pd
import numpy as np
import pandas as pd
# %load_ext autoreload
# %autoreload 2
import warnings
warnings.filterwarnings("ignore")
# Out:
# StatementMeta(, 883cf750-4f95-4e08-8cf4-c3014d4c1a79, 3, Finished, Available)

# %% [markdown]
# ##### Extraemos data necesaria

# %%
df_google_meta = pd.read_csv("/lakehouse/default/" + "Files/DATA_PROCESADA/df_METADATAGOOGLE.csv")
df_google_estados = pd.read_csv("/lakehouse/default/" + "Files/DATA_PROCESADA/df.ESTADOSGOOGLE.csv")
df_businessyelp = pd.read_csv("/lakehouse/default/" + "Files/DATA_PROCESADA/df_BUSINESSYELP.csv")
df_reviewyelp = pd.read_csv("/lakehouse/default/" + "Files/DATA_PROCESADA/df_REVIEWYELP.csv")
# Out:
# StatementMeta(, , , Waiting, )

# %%
df_google_meta
# Out:
# StatementMeta(, , , Waiting, )
#                                              NAME  \
# 0              Los Angeles Public Social Services
# 1        Orange County Social Services Department
# 2                      Midwest D Vision Solutions
# 3                     Chickasha Pre-War Swap Meet
# 4                                        Kasa Mia
# ...                                           ...
# 3025006               Matthew Hayford Photography
# 3025007                        WebsiteTrouble.com
# 3025008      Visitation Management Services (VMS)
# 3025009                  Ivan Hundric Photography
# 3025010              Krystal Richmond Photography
#
#                                                    ADDRESS  \
# 0        Los Angeles Public Social Services, 14545 Lana...
# 1        Orange County Social Services Department, 141 ...
# 2        Midwest D Vision Solutions, 965 W 2480 S, Sout...
# 3         Chickasha Pre-War Swap Meet, Chickasha, OK 73023
# ...

# %%
df_google_meta['ADDRESS'] = df_google_meta['ADDRESS'].fillna('S/D')
# Out:
# StatementMeta(, , , Waiting, )

# %%
df_google_meta.tail(15)
# Out:
# StatementMeta(, , , Waiting, )
#                                          NAME ADDRESS  \
# 3024996                Quick Draw Photo Booth     S/D
# 3024997                         Hub City Bees     S/D
# 3024998                          IMRAN SPORTS     S/D
# 3024999       Dave's Truck & Equipment Repair     S/D
# 3025000                   Vinos de Baja Tours     S/D
# 3025001                           MoldMan LLC     S/D
# 3025002       Gold & Blue Veterinary Wellness     S/D
# 3025003           IntuiTouch Therapeutics LLC     S/D
# 3025004                       DJ Danny Garcia     S/D
# 3025005                  Sherry Olson Studios     S/D
# 3025006           Matthew Hayford Photography     S/D
# 3025007                    WebsiteTrouble.com     S/D
# 3025008  Visitation Management Services (VMS)     S/D
# 3025009              Ivan Hundric Photography     S/D
# 3025010          Krystal Richmond Photography     S/D
#
# ...

# %% [markdown]
# ##### Iniciamos transformaciones necesarias para elaborar el modelo de predicción

# %% [markdown]
# **1. Google Maps**

# %%
#Unimos la data correspondiente a google
df_google = pd.merge(df_google_estados, df_google_meta, on='GMAP_ID', how='inner')
# Out:
# StatementMeta(, , , Waiting, )

# %%
df_google
# Out:
# StatementMeta(, , , Waiting, )
#                USER_ID           NAME_x  RATING  \
# 0         1.052967e+36      Oscar Pérez       2
# 1         1.111244e+36  Henyerli Parada       4
# 2         1.118958e+36  veronica ocando       5
# 3         1.073127e+36            Frank       5
# 4         1.010147e+35  Jose Tallaferro       1
# ...                ...              ...     ...
# 15652917  1.028432e+36           CDL CO       5
# 15652918  1.141624e+36           M Aris       3
# 15652919  1.141624e+36           M Aris       3
# 15652920  1.150063e+36  Javier Banuelos       4
# 15652921  1.150063e+36  Javier Banuelos       4
#
#                                         GMAP_ID    STATE        DATE  \
# 0         0x88f5a756f3e2a719:0xb192d571bc5cfee3  Georgia  2019-07-20
# 1         0x88f5a756f3e2a719:0xb192d571bc5cfee3  Georgia  2019-06-22
# 2         0x88f5a756f3e2a719:0xb192d571bc5cfee3  Georgia  2019-10-19
# 3         0x88f5a756f3e2a719:0xb192d571bc5cfee3  Georgia  2019-08-04
# ...

# %%
df_google = df_google.drop(['GMAP_ID','URL','ADDRESS','USER_ID','NAME_x','AVG_RATING'],axis=1)
# Out:
# StatementMeta(, , , Waiting, )

# %%
df_google = df_google[(df_google['RATING'] > 3.5) & (df_google['SENTIMENT_ANALYSIS'] > 0)]
# Out:
# StatementMeta(, , , Waiting, )

# %%
df_google=df_google.drop('SENTIMENT_ANALYSIS',axis=1)
df_google
# Out:
# StatementMeta(, , , Waiting, )
#           RATING    STATE        DATE         NAME_y  NUM_OF_REVIEWS  \
# 1              4  Georgia  2019-06-22   Don Arepacho             313
# 2              5  Georgia  2019-10-19   Don Arepacho             313
# 3              5  Georgia  2019-08-04   Don Arepacho             313
# 5              5  Georgia  2020-03-08   Don Arepacho             313
# 6              5  Georgia  2019-09-21   Don Arepacho             313
# ...          ...      ...         ...            ...             ...
# 15652909       5   Nevada  2019-02-19  Castle Coffee              24
# 15652916       5   Nevada  2021-06-03  Castle Coffee              24
# 15652917       5   Nevada  2021-06-03  Castle Coffee              24
# 15652920       4   Nevada  2016-05-01  Castle Coffee              24
# 15652921       4   Nevada  2016-05-01  Castle Coffee              24
#
#                        CATEGORY CATEGORY SUMMARY   LATITUDE   LONGITUDE
# ...

# %%
df_google_agrupado = df_google.groupby(['NAME_y','STATE','CATEGORY SUMMARY','LATITUDE','LONGITUDE']).agg({'RATING': 'mean','NUM_OF_REVIEWS': 'sum'}).reset_index()
# Out:
# StatementMeta(, , , Waiting, )

# %%
df_google_agrupado
# Out:
# StatementMeta(, , , Waiting, )
#                                                    NAME_y       STATE  \
# 0                                      "A" Auto Body Shop    Virginia
# 1          "Artcentric" Pottery Painting and Glass Studio  California
# 2                            "BIG VAPE" Vapor Trails, LLC       Texas
# 3       "BLUE ZEBRA" LA ZEBRA AZUL RESTAURANT BAR, NIG...  California
# 4                                        "Easy Insurance"      Nevada
# ...                                                   ...         ...
# 379839                 🔑 🚗EZ Car Keyz Locksmith Camarillo  California
# 379840                             😁 White Smiles of Boca     Florida
# 379841                              🥇 Nectar Lab Kava Bar     Florida
# 379842                               🥇Genesis Window Tint  California
# 379843                      🥇Indio Mufflers & Auto Repair  California
#
#        CATEGORY SUMMARY   LATITUDE   LONGITUDE    RATING  NUM_OF_REVIEWS
# ...

# %%
# Agrupar por ciudades únicas
# ciudades_unicas = df_google_agrupado[['LATITUDE', 'LONGITUDE']].drop_duplicates()
# Out:
# StatementMeta(, , , Waiting, )

# %%
# ciudades_unicas
# Out:
# StatementMeta(, , , Waiting, )

# %%
# from joblib import Parallel, delayed

# # Obtener el número de núcleos de CPU disponibles
# num_cores = 5  # Reemplaza <Número_de_núcleos> con el número de núcleos que deseas utilizar
# api_key = 'AIzaSyDt4mgY5RDkdLhWFiR8q1LgIbpWTus5448'

# # Definir una función para obtener el nombre de la ciudad
# def obtener_nombre_ciudad(row):
#     return get_city(row['LATITUDE'], row['LONGITUDE'], api_key)

# # Aplicar el procesamiento en paralelo para obtener los nombres de las ciudades
# ciudades_unicas['CITY'] = Parallel(n_jobs=num_cores)(delayed(obtener_nombre_ciudad)(row) for index, row in ciudades_unicas.iterrows())
# Out:
# StatementMeta(, , , Waiting, )

# %%
# ciudades_unicas
# Out:
# StatementMeta(, , , Waiting, )

# %%
#Cargamos la data a nuestro lakehouse
#ciudades_unicas.to_csv('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/GOOGLE MAPS/Ciudades_unicas.csv',escapechar='\\')
# Out:
# StatementMeta(, , , Waiting, )

# %%
# Mount external lakehouse  "LH_origen_PFH" into specified local path.
mssparkutils.fs.mount("abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937", "/lakehouse/LH_origen_PFH")

import pandas as pd
# Load data into pandas DataFrame from mssparkutils.fs.getMountPath('/lakehouse/LH_origen_PFH/') + "Files/DATA FINAL/GOOGLE MAPS/Ciudades_unicas.csv"
ciudades_unicas = pd.read_csv(mssparkutils.fs.getMountPath('/lakehouse/LH_origen_PFH/') + "Files/DATA FINAL/GOOGLE MAPS/Ciudades_unicas.csv")
# Out:
# StatementMeta(, , , Waiting, )
# SynapseWidget(Synapse.DataFrame, 13c0621f-4bb4-4352-8729-549e17621e94)

# %%
ciudades_unicas
# Out:
# StatementMeta(, , , Waiting, )
#         Unnamed: 0   LATITUDE   LONGITUDE                    CITY
# 0                0  37.440815  -77.868580      Amelia Court House
# 1                1  38.050382 -122.583503  Lucas Valley-Marinwood
# 2                2  31.632691  -94.411059            Martinsville
# 3                3  38.122706 -121.600563                 Isleton
# 4                4  36.144533 -115.324783               Las Vegas
# ...            ...        ...         ...                     ...
# 375509      379838  34.224890 -119.948282                     NaN
# 375510      379839  34.232839 -119.519640             Carpinteria
# 375511      379840  26.350016  -80.902422                     NaN
# 375512      379842  33.737288 -116.551803                     NaN
# 375513      379843  33.709816 -116.017130               Coachella
#
# [375514 rows x 4 columns]

# %%
numero_nulos = ciudades_unicas['CITY'].isnull().sum()

print("Número de valores nulos en la columna 'CITY':", numero_nulos)
# Out:
# StatementMeta(, , , Waiting, )
# Número de valores nulos en la columna 'CITY': 26538

# %%
ciudades_unicas = ciudades_unicas.dropna(subset=['CITY'])
df_google_agrupado = pd.merge(df_google_agrupado, ciudades_unicas, on=['LATITUDE', 'LONGITUDE'], how='left')
df_google_agrupado
# Out:
# StatementMeta(, , , Waiting, )
#                                                    NAME_y       STATE  \
# 0                                      "A" Auto Body Shop    Virginia
# 1          "Artcentric" Pottery Painting and Glass Studio  California
# 2                            "BIG VAPE" Vapor Trails, LLC       Texas
# 3       "BLUE ZEBRA" LA ZEBRA AZUL RESTAURANT BAR, NIG...  California
# 4                                        "Easy Insurance"      Nevada
# ...                                                   ...         ...
# 379839                 🔑 🚗EZ Car Keyz Locksmith Camarillo  California
# 379840                             😁 White Smiles of Boca     Florida
# 379841                              🥇 Nectar Lab Kava Bar     Florida
# 379842                               🥇Genesis Window Tint  California
# 379843                      🥇Indio Mufflers & Auto Repair  California
#
#        CATEGORY SUMMARY   LATITUDE   LONGITUDE    RATING  NUM_OF_REVIEWS  \
# ...

# %%
df_google_agrupado = df_google_agrupado.dropna(subset=['CITY'])
df_google_agrupado
# Out:
# StatementMeta(, , , Waiting, )
#                                                    NAME_y          STATE  \
# 0                                      "A" Auto Body Shop       Virginia
# 1          "Artcentric" Pottery Painting and Glass Studio     California
# 2                            "BIG VAPE" Vapor Trails, LLC          Texas
# 3       "BLUE ZEBRA" LA ZEBRA AZUL RESTAURANT BAR, NIG...     California
# 4                                        "Easy Insurance"         Nevada
# ...                                                   ...            ...
# 379834                      💐 Affairs to Remember Florist  Massachusetts
# 379835                                 💨 3J's Cigar Davie        Florida
# 379836                            💨 3J's Cigar Lake Worth        Florida
# 379839                 🔑 🚗EZ Car Keyz Locksmith Camarillo     California
# 379843                      🥇Indio Mufflers & Auto Repair     California
#
# ...

# %%
df_google_final = df_google_agrupado.groupby(['STATE','CITY','CATEGORY SUMMARY']).agg({'RATING': 'mean', 'NUM_OF_REVIEWS': 'sum'}).reset_index()
# Out:
# StatementMeta(, , , Waiting, )

# %%
df_google_final
# Out:
# StatementMeta(, , , Waiting, )
#             STATE             CITY CATEGORY SUMMARY    RATING  NUM_OF_REVIEWS
# 0         Alabama           Abanda            Other  4.833333             420
# 1         Alabama        Abbeville   Food and drink  4.869565             759
# 2         Alabama        Abbeville           Health  4.857143             392
# 3         Alabama        Abbeville            Other  4.782451            1562
# 4         Alabama        Abernathy            Other  4.776640            4564
# ...           ...              ...              ...       ...             ...
# 30687  Washington  Zangar Junction            Other  4.788853            2888
# 30688  Washington           Zillah   Food and drink  4.682499           79181
# 30689  Washington           Zillah            Other  4.745505          103056
# 30690  Washington          Zumwalt           Health  4.870130           16401
# 30691  Washington          Zumwalt            Other  4.857143             462
#
# ...

# %%
df_google_final= df_google_final[df_google_final['CATEGORY SUMMARY'] != 'Other']
df_google_final
# Out:
# StatementMeta(, , , Waiting, )
#             STATE          CITY CATEGORY SUMMARY    RATING  NUM_OF_REVIEWS
# 1         Alabama     Abbeville   Food and drink  4.869565             759
# 2         Alabama     Abbeville           Health  4.857143             392
# 7         Alabama    Adamsville             Care  4.857143             812
# 8         Alabama    Adamsville         Cultural  4.625000             658
# 9         Alabama    Adamsville   Food and drink  4.801288           10771
# ...           ...           ...              ...       ...             ...
# 30678  Washington        Yakima        Nightlife  4.526316             874
# 30681  Washington  Yarrow Point   Food and drink  4.751852            5032
# 30684  Washington          Yelm   Food and drink  4.795434          577714
# 30688  Washington        Zillah   Food and drink  4.682499           79181
# 30690  Washington       Zumwalt           Health  4.870130           16401
#
# [15876 rows x 5 columns]

# %%
df_google_final = df_google_final.rename(columns= {'NUM_OF_REVIEWS': 'REVIEW_COUNT'})
# Out:
# StatementMeta(, , , Waiting, )

# %%
#Cargamos la data a nuestro lakehouse
df_google_final.to_csv('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA MODELO/Google_Modelo.csv', index= False, escapechar='\\')
# Out:
# StatementMeta(, , , Waiting, )

# %% [markdown]
# **2.Yelp**

# %%
df_reviewyelp
# Out:
# StatementMeta(, , , Waiting, )
#                       REVIEW_ID                 USER_ID  \
# 0        4-0bwy4XLxtu3iEuG-qstQ  1HM81n6n4iPIFU5d2Lokhw
# 1        bl2_LKL9rAufLLwkauuLKA  1HM81n6n4iPIFU5d2Lokhw
# 2        la_Yav3WMpHJWCa232EllA  1HM81n6n4iPIFU5d2Lokhw
# 3        kdMHtkIz-JaUC7MGJKvauQ  1HM81n6n4iPIFU5d2Lokhw
# 4        Ki0crk5JLcSKmhDyYHRKOQ  1HM81n6n4iPIFU5d2Lokhw
# ...                         ...                     ...
# 6990275  xu9Is80LPAUXmBP6hw9tWg  pY-xUzN-5w8I59pbOaKo-Q
# 6990276  8Kkd-H1hF2K9zDZvoKUcnQ  VNKt38xHvxT8ZzcYk35Buw
# 6990277  ysBY75WimFZRPSzdYUyWzA  8Jk4uBVObos4X9gAkLXQaw
# 6990278  sLvr49BVGIUiNui5KrmK9w  eBthWfRDkwVMs85BC6YfDQ
# 6990279  eskhZmsL_vJosEEhvk-SEA  3ZY4YsPPRfvyvIDsLUSIfA
#
#                     BUSINESS_ID  STARS        DATE  SENTIMENT_ANALYSIS
# 0        oLc7k78_YcDMnMCdbC-h1A      2  2011-10-03                   2
# 1        sR3vWwqzN7vexUpHW72r0A      2  2014-08-11                   2
# ...

# %%
df_reviewyelp = df_reviewyelp[(df_reviewyelp['STARS'] > 3.5) & (df_reviewyelp['SENTIMENT_ANALYSIS'] > 0)]
# Out:
# StatementMeta(, , , Waiting, )

# %%
df_reviewyelp = df_reviewyelp.drop(['DATE','SENTIMENT_ANALYSIS', 'USER_ID', 'REVIEW_ID'],axis=1)
df_reviewyelp
# Out:
# StatementMeta(, , , Waiting, )
#                     BUSINESS_ID  STARS
# 342359   Wr2k0Vz8RbcumYulp-jIrA      5
# 342360   Wr2k0Vz8RbcumYulp-jIrA      5
# 342361   Wr2k0Vz8RbcumYulp-jIrA      5
# 342362   Wr2k0Vz8RbcumYulp-jIrA      5
# 342363   Wr2k0Vz8RbcumYulp-jIrA      5
# ...                         ...    ...
# 6990275  GuzbBFraIq-fbkjfvaTRvg      5
# 6990276  GuzbBFraIq-fbkjfvaTRvg      5
# 6990277  GuzbBFraIq-fbkjfvaTRvg      5
# 6990278  GuzbBFraIq-fbkjfvaTRvg      5
# 6990279  GuzbBFraIq-fbkjfvaTRvg      5
#
# [4598719 rows x 2 columns]

# %%
df_businessyelp
# Out:
# StatementMeta(, , , Waiting, )
#                    BUSINESS_ID                         NAME          CITY  \
# 0       HddE1bPVuTas6hACmHVcUQ                 CVS Pharmacy  Philadelphia
# 1       XPOdKREKlB8uvsMMKNY_7w                 CVS Pharmacy  Philadelphia
# 2       gsG7nNnePxIed34lU7tgLw                 CVS Pharmacy  Philadelphia
# 3       Xr08bwIBEsaQr83aJKQbNg                 CVS Pharmacy  Philadelphia
# 4       myQJP8ZziqXDgQBpfqoTvQ                 CVS Pharmacy  Philadelphia
# ...                        ...                          ...           ...
# 150162  QS884ZcHmkTaWAmjrXyFlg  Miya Lunch Box and Catering  Philadelphia
# 150163  TAjUu0R-Owhu0cFZ4R_I7Q               Tree view cafe  Philadelphia
# 150164  -yxOY_fhwp4uss-8rGTGcA                 Cookie's Bar  Philadelphia
# 150165  _XtUZuRLeTu-TqUjfF_OsQ               Almonte market  Philadelphia
# 150166  qU_CC7nJ-rOfCusuapOW8g             Lucky Restaurant  Philadelphia
#
# ...

# %%
df_businessyelp = df_businessyelp[df_businessyelp['STARS'] > 3.5]
# Out:
# StatementMeta(, , , Waiting, )

# %%
df_businessyelp = df_businessyelp.drop(['CATEGORIES','NAME'],axis=1)
# Out:
# StatementMeta(, , , Waiting, )

# %%
df_businessyelp = df_businessyelp.rename(columns= {'CATEGORIEPERS': 'CATEGORY SUMMARY'})
# Out:
# StatementMeta(, , , Waiting, )

# %%
#Unimos la data correspondiente a yelp
df_yelp1 = pd.merge(df_reviewyelp, df_businessyelp, on='BUSINESS_ID', how='inner')
# Out:
# StatementMeta(, cc494f4d-540d-4700-b49e-c19ebca657c2, 71, Finished, Available)

# %%
df_yelp1[(df_yelp1['CITY'] == 'New Orleans') & (df_yelp1['CATEGORY SUMMARY'] == 'Hotel')]
# Out:
# StatementMeta(, cc494f4d-540d-4700-b49e-c19ebca657c2, 74, Finished, Available)
#                     BUSINESS_ID  STARS_x         CITY STATE   LATITUDE  \
# 51038    o3HubYII2z42Bi8kokVm3A        5  New Orleans    PA  29.956460
# 51039    o3HubYII2z42Bi8kokVm3A        5  New Orleans    PA  29.956460
# 51040    o3HubYII2z42Bi8kokVm3A        5  New Orleans    PA  29.956460
# 51041    o3HubYII2z42Bi8kokVm3A        5  New Orleans    PA  29.956460
# 51042    o3HubYII2z42Bi8kokVm3A        5  New Orleans    PA  29.956460
# ...                         ...      ...          ...   ...        ...
# 3283656  AUpDD9rEJCE_ZYBUnru5oA        5  New Orleans    NJ  29.980765
# 3283657  AUpDD9rEJCE_ZYBUnru5oA        5  New Orleans    NJ  29.980765
# 3283658  AUpDD9rEJCE_ZYBUnru5oA        5  New Orleans    NJ  29.980765
# 3283659  AUpDD9rEJCE_ZYBUnru5oA        5  New Orleans    NJ  29.980765
# 3283660  AUpDD9rEJCE_ZYBUnru5oA        5  New Orleans    NJ  29.980765
#
# ...

# %%
df_yelp1
# Out:
# StatementMeta(, , , Waiting, )
#                     BUSINESS_ID  STARS_x         CITY STATE  LATITUDE  \
# 0        Wr2k0Vz8RbcumYulp-jIrA        5  Cherry Hill    AZ  39.91302
# 1        Wr2k0Vz8RbcumYulp-jIrA        5  Cherry Hill    AZ  39.91302
# 2        Wr2k0Vz8RbcumYulp-jIrA        5  Cherry Hill    AZ  39.91302
# 3        Wr2k0Vz8RbcumYulp-jIrA        5  Cherry Hill    AZ  39.91302
# 4        Wr2k0Vz8RbcumYulp-jIrA        5  Cherry Hill    AZ  39.91302
# ...                         ...      ...          ...   ...       ...
# 3285970  GEcE9Nggevn_h8cOOHWeqg        5         Reno    NJ  39.47780
# 3285971  J9PYIOelORwLsdhfAD0Sgg        5   Doylestown    FL  40.29242
# 3285972  J9PYIOelORwLsdhfAD0Sgg        5   Doylestown    FL  40.29242
# 3285973  J9PYIOelORwLsdhfAD0Sgg        5   Doylestown    FL  40.29242
# 3285974  J9PYIOelORwLsdhfAD0Sgg        5   Doylestown    FL  40.29242
#
#           LONGITUDE  STARS_y  REVIEW_COUNT CATEGORY SUMMARY
# ...

# %%
df_yelp1['RATING'] = (df_yelp1['STARS_x'] + df_yelp1['STARS_y']) /2
# Out:
# StatementMeta(, , , Waiting, )

# %%
df_yelp1 = df_yelp1.drop(['STARS_x', 'STARS_y', 'BUSINESS_ID'],axis=1)
# Out:
# StatementMeta(, , , Waiting, )

# %%
df_yelp1
# Out:
# StatementMeta(, , , Waiting, )
#                 CITY STATE  LATITUDE   LONGITUDE  REVIEW_COUNT  \
# 0        Cherry Hill    AZ  39.91302  -75.002313           411
# 1        Cherry Hill    AZ  39.91302  -75.002313           411
# 2        Cherry Hill    AZ  39.91302  -75.002313           411
# 3        Cherry Hill    AZ  39.91302  -75.002313           411
# 4        Cherry Hill    AZ  39.91302  -75.002313           411
# ...              ...   ...       ...         ...           ...
# 3285970         Reno    NJ  39.47780 -119.762715             5
# 3285971   Doylestown    FL  40.29242  -75.129936             5
# 3285972   Doylestown    FL  40.29242  -75.129936             5
# 3285973   Doylestown    FL  40.29242  -75.129936             5
# 3285974   Doylestown    FL  40.29242  -75.129936             5
#
#         CATEGORY SUMMARY  RATING
# 0         Food and drink     4.5
# 1         Food and drink     4.5
# 2         Food and drink     4.5
# 3         Food and drink     4.5
# ...

# %%
df_yelp_agrupado = df_yelp1.groupby(['STATE','CITY','CATEGORY SUMMARY']).agg({'RATING': 'mean', 'REVIEW_COUNT': 'sum'}).reset_index()
# Out:
# StatementMeta(, , , Waiting, )

# %%
df_yelp_agrupado
# Out:
# StatementMeta(, , , Waiting, )
#       STATE        CITY CATEGORY SUMMARY    RATING  REVIEW_COUNT
# 0        AB    Abington             Care  5.000000            64
# 1        AB    Abington        Education  4.535714            49
# 2        AB    Abington         Shopping  4.333333           192
# 3        AB      Affton   Food and drink  4.310811          1628
# 4        AB       Aldan         Shopping  5.000000            25
# ...     ...         ...              ...       ...           ...
# 16548    TX       Wayne   Food and drink  4.354545          3795
# 16549    UT      Tucson       Automotive  4.333333            42
# 16550    VT  Brookhaven   Food and drink  4.300000            40
# 16551    WA   Haverford             Care  4.500000           117
# 16552   XMS      Tucson             Care  4.731481           783
#
# [16553 rows x 5 columns]

# %%
# Renombramos la columna STATE por 'a' para un mejor manejo de las columnas
df_yelp_agrupado = df_yelp_agrupado.rename(columns= {'STATE': 'a'})
# Out:
# StatementMeta(, , , Waiting, )

# %%
# creamos un diccionario con los valores de la columna 'a' como keys y los values con el nombre del estado completo correspondiente

estados = {"KY": 'Kentucky',
"VA": 'Virginia',
"HI": 'Hawaii',
"MI": 'Michigan',
"SC": 'South Carolina',
"WI": 'Wisconsin',
"NY": 'New York',
"RI": 'Rhode Island',
"NE": 'Nebraska',
"LA": 'Luisiana',
"PA": 'Pennsylvania',
"TN": 'Tennessee',
"MA": 'Massachusetts',
"MN": 'Minnesota',
"MT": 'Montana',
 "OR": 'Oregon',
"WA": 'Washington',
"AL": 'Alabama',
"NH": 'New Hampshire',
"ME": 'Maine',
"WY": 'Wyoming',
 "ID": 'Idaho',
"IN": 'Indiana',
"CT": 'Connecticut',
"DE": 'Delaware',
"CA": 'California',
"NM": 'New Mexico',
"OK": 'Oklahoma',
"SD": 'South Dakota',
"VT": 'Vermont',
"GA": 'Georgia',
"KS": 'Kansas',
"UT": 'Utah',
"CO": 'Colorado',
"NV": 'Nevada',
"NC": 'North Carolina',
"MS": 'Mississippi',
"NJ": 'New Jersey',
"AR": 'Arkansas',
"IA": 'Iowa',
"ND": 'North Dakota',
"FL": 'Florida',
"MO": 'Missouri',
"DC": 'District of Columbia',
"AK": 'Alaska',
"WV": 'West Virginia',
"IL": 'Illinois',
"MD": 'Maryland',
"OH": 'Ohio',
"TX": 'Texas',
"AZ": 'Arizona'}
# Out:
# StatementMeta(, , , Waiting, )

# %%
# Creamos la columnas STATE nuevamente con el nombre completo de los estados tomando como referencia los valores de 'a' para asignar como llaves
df_yelp_agrupado['STATE'] = df_yelp_agrupado['a'].map(estados)
# Out:
# StatementMeta(, , , Waiting, )

# %%
# Identificamos los valores que no corresponden a un lugar dentro de EE.UU
nulos = df_yelp_agrupado[df_yelp_agrupado['STATE'].isna()]
# Out:
# StatementMeta(, , , Waiting, )

# %%
df_yelp_agrupado = df_yelp_agrupado.drop(nulos.index)
# Out:
# StatementMeta(, , , Waiting, )

# %%
df_yelp_final = df_yelp_agrupado.drop(columns= 'a').reset_index(drop= True)
# Out:
# StatementMeta(, , , Waiting, )

# %%
df_yelp_final
# Out:
# StatementMeta(, , , Waiting, )
#              CITY CATEGORY SUMMARY    RATING  REVIEW_COUNT       STATE
# 0        Abington             Care  5.000000            49     Arizona
# 1        Abington   Food and drink  4.612903         11729     Arizona
# 2        Abington          Service  4.750000            36     Arizona
# 3        Abington         Shopping  4.500000            15     Arizona
# 4          Affton   Food and drink  4.596154          1716     Arizona
# ...           ...              ...       ...           ...         ...
# 15676       Boise   Food and drink  4.071429            56       Texas
# 15677       Wayne   Food and drink  4.354545          3795       Texas
# 15678      Tucson       Automotive  4.333333            42        Utah
# 15679  Brookhaven   Food and drink  4.300000            40     Vermont
# 15680   Haverford             Care  4.500000           117  Washington
#
# [15681 rows x 5 columns]

# %%
#Cargamos la data a nuestro lakehouse
df_yelp_final.to_csv('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA MODELO/Yelp_Modelo.csv',index= False, escapechar='\\')
# Out:
# StatementMeta(, , , Waiting, )

# %% [markdown]
# ##### Una vez trabajada toda la data, procedemos a unir cada una de ellas y filtrar segun los requerimientos de nuestro modelo.

# %%
# instanciamos ambos datasets

yelp = pd.read_csv('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA MODELO/Yelp_Modelo.csv')
google = pd.read_csv('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA MODELO/Google_Modelo.csv')
# Out:
# StatementMeta(, 883cf750-4f95-4e08-8cf4-c3014d4c1a79, 4, Finished, Available)

# %%
# unimos los dataframes en un solo dataframe
df_total = pd.concat([google,yelp])
# Out:
# StatementMeta(, 883cf750-4f95-4e08-8cf4-c3014d4c1a79, 48, Finished, Available)

# %%
df_total[(df_total['CITY'] == 'New Orleans') & (df_total['CATEGORY SUMMARY'] == 'Hotel')]
# Out:
# StatementMeta(, 883cf750-4f95-4e08-8cf4-c3014d4c1a79, 7, Finished, Available)
#               STATE         CITY CATEGORY SUMMARY    RATING  REVIEW_COUNT
# 712         Arizona  New Orleans            Hotel  4.867600        217499
# 1712     California  New Orleans            Hotel  4.364873        457561
# 2333       Delaware  New Orleans            Hotel  4.812950         82430
# 3744        Florida  New Orleans            Hotel  4.724675       1128506
# 5066          Idaho  New Orleans            Hotel  4.440299          2750
# 5681       Illinois  New Orleans            Hotel  4.331989        192324
# 6670        Indiana  New Orleans            Hotel  4.663043         29295
# 7955       Luisiana  New Orleans            Hotel  4.671193       2542715
# 9206       Missouri  New Orleans            Hotel  4.566860         81229
# 10412    New Jersey  New Orleans            Hotel  4.619715        170275
# 11529        Nevada  New Orleans            Hotel  4.570419        882843
# ...

# %%
df_total
# Out:
# StatementMeta(, , , Waiting, )
#             STATE        CITY CATEGORY SUMMARY    RATING  REVIEW_COUNT
# 0         Alabama   Abbeville   Food and drink  4.869565           759
# 1         Alabama   Abbeville           Health  4.857143           392
# 2         Alabama  Adamsville             Care  4.857143           812
# 3         Alabama  Adamsville         Cultural  4.625000           658
# 4         Alabama  Adamsville   Food and drink  4.801288         10771
# ...           ...         ...              ...       ...           ...
# 15676       Texas       Boise   Food and drink  4.071429            56
# 15677       Texas       Wayne   Food and drink  4.354545          3795
# 15678        Utah      Tucson       Automotive  4.333333            42
# 15679     Vermont  Brookhaven   Food and drink  4.300000            40
# 15680  Washington   Haverford             Care  4.500000           117
#
# [31557 rows x 5 columns]

# %%
df_total

# %%
df_total['CATEGORY SUMMARY'].unique()
# Out:
# StatementMeta(, , , Waiting, )
# array(['Food and drink', 'Health', 'Care', 'Cultural', 'Shopping',
#        'Hostel', 'Nightlife', 'Religion', 'Education', 'Service', 'Media',
#        'Pets', 'Automotive', 'Entertainment', 'Hotel', 'Rent a Car'],
#       dtype=object)

# %%
df_total['RATING_HOTEL'] = df_total['RATING'][df_total['CATEGORY SUMMARY'] == 'Hostel']
# Out:
# StatementMeta(, 883cf750-4f95-4e08-8cf4-c3014d4c1a79, 49, Finished, Available)

# %%
df_total[(df_total['CITY'] == 'New Orleans') & (df_total['CATEGORY SUMMARY'] == 'Hostel')]
# Out:
# StatementMeta(, 883cf750-4f95-4e08-8cf4-c3014d4c1a79, 23, Finished, Available)
#           STATE         CITY CATEGORY SUMMARY  RATING  REVIEW_COUNT  \
# 6156  Louisiana  New Orleans           Hostel  4.6625          2352
#
#       RATING_HOTEL
# 6156        4.6625

# %%
df_total['RATING_HOTEL'] = df_total['RATING_HOTEL'].fillna(df_total[df_total['CATEGORY SUMMARY'] == 'Hotel']['RATING']).fillna(0)
df_total
# Out:
# StatementMeta(, 883cf750-4f95-4e08-8cf4-c3014d4c1a79, 50, Finished, Available)
#             STATE        CITY CATEGORY SUMMARY    RATING  REVIEW_COUNT  \
# 0         Alabama   Abbeville   Food and drink  4.869565           759
# 1         Alabama   Abbeville           Health  4.857143           392
# 2         Alabama  Adamsville             Care  4.857143           812
# 3         Alabama  Adamsville         Cultural  4.625000           658
# 4         Alabama  Adamsville   Food and drink  4.801288         10771
# ...           ...         ...              ...       ...           ...
# 15676       Texas       Boise   Food and drink  4.071429            56
# 15677       Texas       Wayne   Food and drink  4.354545          3795
# 15678        Utah      Tucson       Automotive  4.333333            42
# 15679     Vermont  Brookhaven   Food and drink  4.300000            40
# 15680  Washington   Haverford             Care  4.500000           117
#
#        RATING_HOTEL
# ...

# %%
df_total[(df_total['CITY'] == 'New Orleans') & (df_total['CATEGORY SUMMARY'] == 'Hotel')]
# Out:
# StatementMeta(, 883cf750-4f95-4e08-8cf4-c3014d4c1a79, 51, Finished, Available)
#               STATE         CITY CATEGORY SUMMARY    RATING  REVIEW_COUNT  \
# 712         Arizona  New Orleans            Hotel  4.867600        217499
# 1712     California  New Orleans            Hotel  4.364873        457561
# 2333       Delaware  New Orleans            Hotel  4.812950         82430
# 3744        Florida  New Orleans            Hotel  4.724675       1128506
# 5066          Idaho  New Orleans            Hotel  4.440299          2750
# 5681       Illinois  New Orleans            Hotel  4.331989        192324
# 6670        Indiana  New Orleans            Hotel  4.663043         29295
# 7955       Luisiana  New Orleans            Hotel  4.671193       2542715
# 9206       Missouri  New Orleans            Hotel  4.566860         81229
# 10412    New Jersey  New Orleans            Hotel  4.619715        170275
# 11529        Nevada  New Orleans            Hotel  4.570419        882843
# ...

# %%
df_total1 = df_total.groupby(['STATE','CITY']).agg({'RATING': 'mean', 'REVIEW_COUNT': 'sum', 'RATING_HOTEL': 'sum'}).reset_index()
# Out:
# StatementMeta(, 883cf750-4f95-4e08-8cf4-c3014d4c1a79, 53, Finished, Available)

# %%
df_total1[(df_total1['CITY'] == 'New Orleans')]
# Out:
# StatementMeta(, 883cf750-4f95-4e08-8cf4-c3014d4c1a79, 59, Finished, Available)
#               STATE         CITY    RATING  REVIEW_COUNT  RATING_HOTEL
# 753         Arizona  New Orleans  4.686483      60365459      4.867600
# 1763     California  New Orleans  4.579929       9864463      4.364873
# 2540       Delaware  New Orleans  4.686130       2299238      4.812950
# 3359        Florida  New Orleans  4.608423      98535334      4.724675
# 4083         Hawaii  New Orleans  4.718750           288      0.000000
# 4265          Idaho  New Orleans  4.600424      18668546      4.440299
# 4536       Illinois  New Orleans  4.554695        696639      4.331989
# 4896        Indiana  New Orleans  4.622252      12564220      4.663043
# 5357      Louisiana  New Orleans  4.785608       1325553      4.662500
# 5757       Luisiana  New Orleans  4.599158      30527210      4.714907
# 7331       Missouri  New Orleans  4.610553      55235800      4.566860
# ...

# %%
df_total1[df_total1['RATING_HOTEL'] > 5.1].sort_values(by= 'RATING_HOTEL', ascending= False)
# Out:
# StatementMeta(, 883cf750-4f95-4e08-8cf4-c3014d4c1a79, 58, Finished, Available)
# Empty DataFrame
# Columns: [STATE, CITY, RATING, REVIEW_COUNT, RATING_HOTEL]
# Index: []

# %%
# Definir las condiciones
condicion_1 = (df_total1['RATING_HOTEL'] > 5.1) & (df_total1['RATING_HOTEL'] <= 10)
condicion_2 = (df_total1['RATING_HOTEL'] > 10) & (df_total1['RATING_HOTEL'] <= 15)
condicion_3 = (df_total1['RATING_HOTEL'] > 15)

# Aplicar las condiciones y dividir los valores correspondientes
df_total1.loc[condicion_1, 'RATING_HOTEL'] /= 2
df_total1.loc[condicion_2, 'RATING_HOTEL'] /= 3
df_total1.loc[condicion_3, 'RATING_HOTEL'] /= 4
# Out:
# StatementMeta(, 883cf750-4f95-4e08-8cf4-c3014d4c1a79, 55, Finished, Available)

# %%
df_total1
# Out:
# StatementMeta(, 883cf750-4f95-4e08-8cf4-c3014d4c1a79, 56, Finished, Available)
#             STATE          CITY    RATING  REVIEW_COUNT  RATING_HOTEL
# 0         Alabama     Abbeville  4.863354          1151           0.0
# 1         Alabama    Adamsville  4.729949         12439           0.0
# 2         Alabama       Addison  4.743869         92302           0.0
# 3         Alabama      Agricola  4.709686          7940           0.0
# 4         Alabama     Alabaster  4.707449         59544           0.0
# ...           ...           ...       ...           ...           ...
# 13441  Washington        Yakima  4.735437        398694           0.0
# 13442  Washington  Yarrow Point  4.751852          5032           0.0
# 13443  Washington          Yelm  4.795434        577714           0.0
# 13444  Washington        Zillah  4.682499         79181           0.0
# 13445  Washington       Zumwalt  4.870130         16401           0.0
#
# [13446 rows x 5 columns]

# %%
df_total1[df_total1['RATING_HOTEL'] != 0.0]
# Out:
# StatementMeta(, 883cf750-4f95-4e08-8cf4-c3014d4c1a79, 60, Finished, Available)
#             STATE         CITY    RATING  REVIEW_COUNT  RATING_HOTEL
# 10        Alabama       Alpine  4.722010        586757      4.670732
# 14        Alabama     Anniston  4.653680          3045      4.545455
# 25        Alabama       Athens  4.708370       4060927      4.487103
# 27        Alabama       Auburn  4.796796         97516      4.538462
# 37        Alabama  Bay Minette  4.802613         57737      4.642857
# ...           ...          ...       ...           ...           ...
# 13400  Washington       Tumtum  4.748718          2602      4.897436
# 13405  Washington        Union  4.471698         13621      4.471698
# 13412  Washington    Vancouver  4.715451       8983624      4.500000
# 13417  Washington      Waldron  4.793631        253000      4.818182
# 13419  Washington  Walla Walla  4.758757          6716      4.500000
#
# [1924 rows x 5 columns]

# %%
df_total1.sort_values(by= ['REVIEW_COUNT', 'RATING'], ascending= (False, False))
# Out:
# StatementMeta(, 883cf750-4f95-4e08-8cf4-c3014d4c1a79, 61, Finished, Available)
#               STATE              CITY    RATING  REVIEW_COUNT  RATING_HOTEL
# 3359        Florida       New Orleans  4.608423      98535334      4.724675
# 10241  Pennsylvania      Philadelphia  4.594677      90451346      4.474359
# 10190  Pennsylvania       New Orleans  4.599039      87491533      4.647614
# 3420        Florida           Orlando  4.833766      73023690      4.766667
# 7836         Nevada           Pahrump  4.824571      70423515      4.721092
# ...             ...               ...       ...           ...           ...
# 10076  Pennsylvania  Jefferson Parish  4.333333            15      0.000000
# 10140  Pennsylvania       Marshallton  4.333333            15      0.000000
# 9935   Pennsylvania   Crystal Springs  4.166667            15      0.000000
# 933         Arizona        Wood River  4.500000            10      0.000000
# ...

# %%
df_total1.sort_values(by= ['RATING', 'REVIEW_COUNT'], ascending= (False, False))
# Out:
# StatementMeta(, cc494f4d-540d-4700-b49e-c19ebca657c2, 82, Finished, Available)
#               STATE             CITY CATEGORY SUMMARY  RATING  REVIEW_COUNT  \
# 8551    Mississippi       New Albany           Health     5.0         23552
# 13107         Texas       Round Rock             Care     5.0         12716
# 7502       Luisiana       Doylestown         Shopping     5.0         11929
# 5032        Florida   Tarpon Springs             Care     5.0         11161
# 4663        Florida        Opa-locka   Food and drink     5.0          8414
# ...             ...              ...              ...     ...           ...
# 13074  Pennsylvania        Liverpool   Food and drink     4.0            20
# 14790    Washington  Anderson Island         Cultural     4.0            18
# 3870        Florida         Palmetto   Food and drink     4.0            15
# 5623       Illinois        Levittown   Food and drink     4.0            15
# ...

# %%
#Cargamos la data a nuestro lakehouse
df_total1.to_csv('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA MODELO/data_final_Modelo.csv',index= False, escapechar='\\')
# Out:
# StatementMeta(, 883cf750-4f95-4e08-8cf4-c3014d4c1a79, 62, Finished, Available)
