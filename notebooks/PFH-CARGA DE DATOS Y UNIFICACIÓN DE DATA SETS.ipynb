# %%
import os
import pandas as pd
import numpy as np
import pyarrow as pa
import pyarrow.parquet as pq
import pickle
import warnings
warnings.filterwarnings(action= 'ignore')
# Out:
# StatementMeta(, 87fe4d1d-e24e-4521-b538-2da44ed80b47, 3, Finished, Available)

# %% [markdown]
# **METADATA**

# %%
# Importar la biblioteca pandas
import pandas as pd

# Cargar los datasets en DataFrames
df1 = pd.read_parquet("abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/df_unido_metadata1.parquet")
df2 = pd.read_parquet("abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/df_unido_metadata2.parquet")
df3 = pd.read_parquet("abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/df_unido_metadata3.parquet")

# Unir los DataFrames
metadata= pd.concat([df1, df2, df3], ignore_index=True)

# Verificar el DataFrame resultante
print(metadata.head())  # Mostrar las primeras filas del DataFrame resultante
# Out:
# StatementMeta(, 1136c6a4-091a-4ea6-8817-8cd3a1a691cb, 4, Finished, Available)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 5
#       2 import pandas as pd
#       4 # Cargar los datasets en DataFrames
# ----> 5 df1 = pd.read_parquet("abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/df_unido_metadata1.parquet")
#       6 df2 = pd.read_parquet("abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/df_unido_metadata2.parquet")
#       7 df3 = pd.read_parquet("abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/df_unido_metadata3.parquet")
#
# ...

# %%
# Guardar el DataFrame resultante como un solo archivo Parquet
metadata.to_csv("abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/metadata.csv", index=False)
# Out:
# StatementMeta(, , , Waiting, )

# %%
#Leemos el dataframe desde el directorio donde guardamos el archivo
metadata = pd.read_csv('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/GOOGLE MAPS/metadata.csv')
metadata.info()
# Out:
# StatementMeta(, ffe952f3-a021-4928-b97c-98a9f434a4c9, 4, Finished, Available)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3025011 entries, 0 to 3025010
# Data columns (total 15 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   name              object
#  1   address           object
#  2   gmap_id           object
#  3   description       object
#  4   latitude          float64
#  5   longitude         float64
#  6   category          object
#  7   avg_rating        float64
#  8   num_of_reviews    int64
#  9   price             object
#  10  hours             object
#  11  MISC              object
#  12  state             object
#  13  relative_results  object
#  14  url               object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 346.2+ MB

# %% [markdown]
# **ESTADOS**

# %%
alabama = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Alabama.parquet')
alaska = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Alaska.parquet')
arizona = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Arizona.parquet')
arkansas = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Arkansas.parquet')
california = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_California.parquet')
colorado = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Colorado.parquet')
connecticut = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Connecticut.parquet')
delaware = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Delaware.parquet')
districtofcolumbia = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_District_of_Columbia.parquet')
florida = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Florida.parquet')
georgia = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Georgia.parquet')
hawaii = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Hawaii.parquet')
idaho = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Idaho.parquet')
illinois = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Illinois.parquet')
indiana = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Indiana.parquet')
iowa = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Iowa.parquet')
kansas = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Kansas.parquet')
kentucky = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Kentucky.parquet')
louisiana = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Louisiana.parquet')
maine = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Maine.parquet')
maryland = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Maryland.parquet')
massachusets = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Massachusetts.parquet')
michigan = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Michigan.parquet')
minnesota = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Minnesota.parquet')
mississippi = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Mississippi.parquet')
missouri = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Missouri.parquet')
montana = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Montana.parquet')
nebraska = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Nebraska.parquet')
nevada = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Nevada.parquet')
newhampshire = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_New_Hampshire.parquet')
newjersey = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_New_Jersey.parquet')
newmexico = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_New_Mexico.parquet')
newyork = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_New_York.parquet')
northcarolina = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_North_Carolina.parquet')
northdakota = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_North_Dakota.parquet')
ohio = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Ohio.parquet')
oklahoma = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Oklahoma.parquet')
oregon = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Oregon.parquet')
pennsylvania = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Pennsylvania.parquet')
rhodeisland = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Rhode_Island.parquet')
southcarolina = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_South_Carolina.parquet')
southdakota = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_South_Dakota.parquet')
tennessee = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Tennessee.parquet')
texas = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Texas.parquet')
utah = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Utah.parquet')
vermont = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Vermont.parquet')
virginia = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Virginia.parquet')
washington = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Washington.parquet')
westvirginia = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_West_Virginia.parquet')
wisconsin = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Wisconsin.parquet')
wyoming = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA ORIGINAL/GOOGLE MAPS/REVIEWS ESTADOS/df_unido_Wyoming.parquet')
# Out:
# StatementMeta(, fc15f77e-4f7d-4314-8ffa-7714023f64f4, 4, Finished, Available)

# %%
# Creas una lista de todos los dataframes
lista_dataframes = [
    alabama, alaska, arizona, arkansas, california, colorado, connecticut, delaware, districtofcolumbia, florida, georgia, hawaii, idaho, 
    illinois, indiana, iowa, kansas, kentucky, louisiana, maine, maryland, massachusets, michigan, minnesota, mississippi, missouri, montana, 
    nebraska, nevada, newhampshire, newjersey, newmexico, newyork, northcarolina, northdakota, ohio, oklahoma, oregon, pennsylvania, rhodeisland, southcarolina,
    southdakota, tennessee, texas, utah, vermont, virginia, washington, westvirginia, wisconsin, wyoming
    ]

# Agregas la columna 'estado' a cada dataframe y les asignas el nombre correspondiente
for estado, df_estado in zip([
    'Alabama' , 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 
    'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 
    'Nebraska', 'Nevada', 'New Hampshire','New Jersey','New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina',
    'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
    lista_dataframes):
    df_estado['estado'] = estado

# Realizas el merge de todos los dataframes
estados = pd.concat(lista_dataframes, ignore_index=True)

# Ahora df_final contendrá todos los datos de los estados con una columna adicional 'estado'
# Out:
# StatementMeta(, fc15f77e-4f7d-4314-8ffa-7714023f64f4, 5, Finished, Available)

# %%
# Guarda el DataFrame como un archivo CSV con un carácter de escape especificado
# estados.to_csv("abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/GOOGLE MAPS/estados.csv", escapechar='\\')
estados.to_csv("abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/estados.csv", escapechar='\\')
# Out:
# StatementMeta(, fc15f77e-4f7d-4314-8ffa-7714023f64f4, 6, Finished, Available)

# %%
estados= pd.read_csv('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/GOOGLE MAPS/estados.csv')
# Out:
# StatementMeta(, 2625ffca-ed5d-4f93-9940-030d8eaf6488, 4, Finished, Available)

# %%
estados.head()
# Out:
# StatementMeta(, fc15f77e-4f7d-4314-8ffa-7714023f64f4, 8, Finished, Available)
#         user_id                    name           time  rating  \
# 0  1.140438e+20           Kanisha Mixon  1597168272670       5
# 1  1.160090e+20          Brandie Hodges  1609899039594       5
# 2  1.062399e+20             Sharon King  1547235290843       4
# 3  1.049701e+20         Veronica Pierce  1517709403534       5
# 4  1.105875e+20  Whitney Waldon Collier  1535245718492       5
#
#                                                 text  pics  resp  \
# 0  Very Personable staff! Beautiful and clean env...  None  None
# 1                               Best clothing intown  None  None
# 2                                               None  None  None
# 3                                               None  None  None
# 4                                               None  None  None
#
#                                  gmap_id   estado
# 0  0x8862134e67ff5c87:0x38b5e2ae99cd1fcf  Alabama
# ...

# %%
estados['estado'].unique()
# Out:
# StatementMeta(, 2625ffca-ed5d-4f93-9940-030d8eaf6488, 5, Finished, Available)
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
estados.info()
# Out:
# StatementMeta(, fc15f77e-4f7d-4314-8ffa-7714023f64f4, 9, Finished, Available)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81396359 entries, 0 to 81396358
# Data columns (total 9 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   user_id  float64
#  1   name     object
#  2   time     int64
#  3   rating   int64
#  4   text     object
#  5   pics     object
#  6   resp     object
#  7   gmap_id  object
#  8   estado   object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 5.5+ GB

# %% [markdown]
# **TRIP ADVISOR**

# %%
trip1 = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/TRIP ADVISOR/Reviews Tripadvisor.parquet/part-00000-bb534fa8-b544-46f4-8dfa-fe71e8be3ee2-c000.snappy.parquet')
trip2 = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/TRIP ADVISOR/Reviews Tripadvisor.parquet/part-00001-bb534fa8-b544-46f4-8dfa-fe71e8be3ee2-c000.snappy.parquet')
trip3 = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/TRIP ADVISOR/Reviews Tripadvisor.parquet/part-00002-bb534fa8-b544-46f4-8dfa-fe71e8be3ee2-c000.snappy.parquet')
trip4 = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/TRIP ADVISOR/Reviews Tripadvisor.parquet/part-00003-bb534fa8-b544-46f4-8dfa-fe71e8be3ee2-c000.snappy.parquet')
trip5 = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/TRIP ADVISOR/Reviews Tripadvisor.parquet/part-00004-bb534fa8-b544-46f4-8dfa-fe71e8be3ee2-c000.snappy.parquet')
trip6 = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/TRIP ADVISOR/Reviews Tripadvisor.parquet/part-00005-bb534fa8-b544-46f4-8dfa-fe71e8be3ee2-c000.snappy.parquet')
trip7 = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/TRIP ADVISOR/Reviews Tripadvisor.parquet/part-00006-bb534fa8-b544-46f4-8dfa-fe71e8be3ee2-c000.snappy.parquet')
trip8 = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/TRIP ADVISOR/Reviews Tripadvisor.parquet/part-00007-bb534fa8-b544-46f4-8dfa-fe71e8be3ee2-c000.snappy.parquet')
# Out:
# StatementMeta(, 87fe4d1d-e24e-4521-b538-2da44ed80b47, 4, Finished, Available)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 trip1 = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/TRIP ADVISOR/Reviews Tripadvisor.parquet/part-00000-bb534fa8-b544-46f4-8dfa-fe71e8be3ee2-c000.snappy.parquet')
#       2 trip2 = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/TRIP ADVISOR/Reviews Tripadvisor.parquet/part-00001-bb534fa8-b544-46f4-8dfa-fe71e8be3ee2-c000.snappy.parquet')
# ...

# %%
tripu1 = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/TRIP ADVISOR/Busqueda de ubicaciones.parquet/part-00000-036e69ae-ae4f-47b4-9809-aec019065539-c000.snappy.parquet')
tripu2 = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/TRIP ADVISOR/Busqueda de ubicaciones.parquet/part-00007-036e69ae-ae4f-47b4-9809-aec019065539-c000.snappy.parquet')
# Out:
# StatementMeta(, 1136c6a4-091a-4ea6-8817-8cd3a1a691cb, 5, Finished, Available)

# %%
lista_dataframes = [
    trip1, trip2, trip3, trip4, trip5, trip6, trip7, trip8
    ]

# Realizas el merge de todos los dataframes
tripadvisor = pd.concat(lista_dataframes, ignore_index=True)
# Out:
# StatementMeta(, cb411468-1504-46ff-816e-8ba62f99c94d, 5, Finished, Available)

# %%
tripadvisor.to_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/TRIP ADVISOR/tripadvisor.parquet')
tripadvisor = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/TRIP ADVISOR/tripadvisor.parquet')
tripadvisor.head()
# Out:
# StatementMeta(, cb411468-1504-46ff-816e-8ba62f99c94d, 6, Finished, Available)
#           ID  Location ID        Published Date  Rating  Helpful Votes  \
# 0  945282250      3507454  2024-04-04T00:17:49Z       2              0
# 1  944587799       104723  2024-03-30T22:31:09Z       5              0
# 2  945441447       509147  2024-04-05T08:34:33Z       5              0
# 3  943797002     13433273  2024-03-25T14:51:47Z       5              0
# 4  946015975      2040848  2024-04-09T21:17:35Z       5              0
#
#                                                 Text  \
# 0  Everything would have been great in our 4th fl...
# 1  Fantastic. History (especially womens history)...
# 2  Some of the best fried chicken in Georgia for ...
# 3  This hotel was a gold mine as far was we were ...
# 4  Fantastic food, atmosphere & service. The seaf...
#
#                                          Title    Trip Type Travel Date  \
# ...

# %%
tripadvisor.info()
# Out:
# StatementMeta(, cb411468-1504-46ff-816e-8ba62f99c94d, 7, Finished, Available)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3739 entries, 0 to 3738
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              3739 non-null   int64
#  1   Location ID     3739 non-null   int64
#  2   Published Date  3739 non-null   object
#  3   Rating          3739 non-null   int64
#  4   Helpful Votes   3739 non-null   int64
#  5   Text            3739 non-null   object
#  6   Title           3739 non-null   object
#  7   Trip Type       3737 non-null   object
#  8   Travel Date     3737 non-null   object
#  9   Username        3737 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 292.2+ KB

# %%
lista_dataframes = [
    tripu1, tripu2]

# Realizas el merge de todos los dataframes
tripadvisorubi = pd.concat(lista_dataframes, ignore_index=True)
# Out:
# StatementMeta(, 1136c6a4-091a-4ea6-8817-8cd3a1a691cb, 6, Finished, Available)

# %%
tripadvisor = pd.read_csv('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/TRIP ADVISOR/APIs_Tripadvisor.csv')
tripadvisor.head()
# Out:
# StatementMeta(, 87fe4d1d-e24e-4521-b538-2da44ed80b47, 5, Finished, Available)
#             ID  Location ID        Published Date  Rating  Helpful Votes  \
# 0  947329195.0    2614958.0  2024-04-18T11:06:09Z     5.0            0.0
# 1  947310630.0    2614958.0  2024-04-18T08:23:19Z     5.0            0.0
# 2  947113254.0     227540.0  2024-04-17T21:59:56Z     5.0            0.0
# 3  947110191.0     224508.0  2024-04-17T21:02:14Z     1.0            0.0
# 4  947107142.0   10163307.0  2024-04-17T19:52:57Z     5.0            1.0
#
#                                                 Text  \
# 0  Captain Troy and 1st mate Sam provided a first...
# 1  We had a fantastic time with Captain Troy and ...
# 2  Just want to share my good experience here. Wh...
# 3  I walked into Hampton Inn in Birmingham-Pelham...
# 4  My family & I had a wonderful experience at th...
#
#                                          Title        Trip Type Travel Date  \
# ...

# %% [markdown]
# **CENSO**

# %%
censo1 = pd.read_csv('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/CENSO/Current_Population_Survey2011.csv')
censo2 = pd.read_csv('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/CENSO/Current_Population_Survey2012.csv')
censo3 = pd.read_csv('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/CENSO/Current_Population_Survey2013.csv')
censo4 = pd.read_csv('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/CENSO/Current_Population_Survey2014.csv')
censo5 = pd.read_csv('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/CENSO/Current_Population_Survey2015.csv')
censo6 = pd.read_csv('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/CENSO/Current_Population_Survey2016.csv')
censo7 = pd.read_csv('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/CENSO/Current_Population_Survey2017.csv')
censo8 = pd.read_csv('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/CENSO/Current_Population_Survey2018.csv')
censo9 = pd.read_csv('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/CENSO/Current_Population_Survey2019.csv')
censo10 = pd.read_csv('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/CENSO/Current_Population_Survey2020.csv')
censo11 = pd.read_csv('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/CENSO/Current_Population_Survey2021.csv')
censo12 = pd.read_csv('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/CENSO/Current_Population_Survey2022.csv')
censo13 = pd.read_csv('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/CENSO/Current_Population_Survey2023.csv')
# Out:
# StatementMeta(, d0892841-af0a-40b6-b565-8eb5392892f9, 4, Finished, Available)

# %%
lista_dataframes = [
    censo1, censo2, censo3, censo4, censo5, censo6, censo7, censo8, censo9, censo10, censo11, censo12, censo13
    ]

# Realizas el merge de todos los dataframes
censo = pd.concat(lista_dataframes, ignore_index=True)
# Out:
# StatementMeta(, d0892841-af0a-40b6-b565-8eb5392892f9, 5, Finished, Available)

# %%
censo.to_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/CENSO/censo.parquet')
censo = pd.read_parquet('abfss://558991ad-6fdf-463a-b58a-238ddabaa398@onelake.dfs.fabric.microsoft.com/37a0382d-f783-4728-a697-48b1dc002937/Files/DATA FINAL/censo.parquet')
censo.head()
# Out:
# StatementMeta(, d0892841-af0a-40b6-b565-8eb5392892f9, 6, Finished, Available)
#    HRNUMHOU  PTERNH1O  PEMNTVTY  PEFNTVTY  GTCBSASZ  GESTFIPS  GTCSA  PRCHLD  \
# 0         2     -0.01        57        57         5         1      0       4
# 1         2     -0.01        57        57         5         1      0       0
# 2         4     -0.01        57        57         2         1      0       0
# 3         4     -0.01        57        57         2         1      0       0
# 4         4     13.60        57        57         2         1      0       0
#
#    PRTAGE  PESEX  GTCBSA  HEFAMINC  HRHTYPE  state  Año_registro
# 0      40      1   13820         7        3      1          2011
# 1      16      2   13820         7        3      1          2011
# 2      53      2   11500         8        7      1          2011
# 3      52      1   11500         8        7      1          2011
# 4      27      1   11500         8        7      1          2011

# %%
censo.info()
# Out:
# StatementMeta(, d0892841-af0a-40b6-b565-8eb5392892f9, 7, Finished, Available)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1575735 entries, 0 to 1575734
# Data columns (total 15 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   HRNUMHOU      1575735 non-null  int64
#  1   PTERNH1O      1575735 non-null  float64
#  2   PEMNTVTY      1575735 non-null  int64
#  3   PEFNTVTY      1575735 non-null  int64
#  4   GTCBSASZ      1575735 non-null  int64
#  5   GESTFIPS      1575735 non-null  int64
#  6   GTCSA         1575735 non-null  int64
#  7   PRCHLD        1575735 non-null  int64
#  8   PRTAGE        1575735 non-null  int64
#  9   PESEX         1575735 non-null  int64
#  10  GTCBSA        1575735 non-null  int64
#  11  HEFAMINC      1575735 non-null  int64
#  12  HRHTYPE       1575735 non-null  int64
#  13  state         1575735 non-null  int64
#  14  Año_registro  1575735 non-null  int64
# dtypes: float64(1), int64(14)
# ...
